# %%
import datetime
import calendar
import matplotlib.pyplot as plt
import random
from matplotlib.pyplot import MultipleLocator


date = '2020-03-10'

weekday = datetime.datetime.strptime(date, '%Y-%m-%d').weekday()
weekday
# Out:
# 1

# %%
startDate = datetime.datetime.fromisoformat('2019-12-12')
endDate = startDate + datetime.timedelta(days=3)
x = endDate == startDate

def fun(startDate, endDate, weekDay):
    day = startDate
    while day < endDate:
        print(day, day.strftime('%Y-%m-%d'))
        day = day + datetime.timedelta(days=1)

fun(startDate, endDate, 1)
print(endDate)
first_day = datetime.datetime(startDate.year, startDate.month, 1)
days_num = calendar.monthrange(first_day.year, first_day.month)[1] #获取一个月有多少天
first_day_of_next_month = first_day + datetime.timedelta(days = days_num) #当月的最后一天只需要days_num-1即可
first_day_of_next_month
# Out:
# 2019-12-12 00:00:00 2019-12-12
# 2019-12-13 00:00:00 2019-12-13
# 2019-12-14 00:00:00 2019-12-14
# 2019-12-15 00:00:00
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
num = 100
x = []
y = []
x_lables = []
for index in range(0, num):
    x.append(index)
    x_lables.append('A_' + str(index))
    y.append(random.randint(10,100))

plt.plot(x,y,label='Frist line',linewidth=1,color='r')


plt.xlabel('Plot Number')
plt.ylabel('Important var')
plt.title('Interesting Graph\nCheck it out')
#plt.legend()

#plt.xticks(x, x_lables)

x_major_locator=MultipleLocator(10)
ax=plt.gca()
#ax.xaxis.set_major_locator(x_major_locator)
plt.xticks(x[::10], x_lables[::10])

plt.show()
print(x_lables[::10])
# Out:
# ['A_0', 'A_10', 'A_20', 'A_30', 'A_40', 'A_50', 'A_60', 'A_70', 'A_80', 'A_90']

# %%
def
